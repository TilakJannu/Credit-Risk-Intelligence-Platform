# %% [markdown]
# # Credit Risk Intelligence Platform EDA
#
# This notebook delegates to `notebooks/eda.py` so the EDA phase is reproducible from scripts and notebooks.

# %%
from notebooks.eda import generate_eda_outputs

report = generate_eda_outputs()
report
